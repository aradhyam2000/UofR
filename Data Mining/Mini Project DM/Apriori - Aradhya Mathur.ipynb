# %%
import pandas as pd
import timeit
import numpy as np

#Reading Dataset
df = pd.read_csv('adult.data', sep=",", header = None , na_values = "?")
df.head()
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# 3   United-States   <=50K
# 4            Cuba   <=50K

# %%
#Adding column names in the Dataset
df.columns = ['age', 'workclass','fnlwgt','education', 'education_num', 'marital_status', 'occupation', 'relationship', 'race',
              'sex', 'capital_gain', 'capital_loss','hours_per_week','native_country', 'class']
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country   class
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#         class
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]

# %%
#Preprocessing
#Converting continuous data into Categorical data
df['Age'] = pd.cut(x=df['age'], bins=[0, 18, 30, 50, 1000], labels=['Underage', 'Young', 'Adult','Elderly'])
#In this I have divided Age into 4 categories
#Similarly done for hours per week
df['Hours_per_Week'] = pd.cut(x=df['hours_per_week'], bins=[0, 20, 40, 1000], labels=['Part-Time', 'Full-Time', 'Overtime'])
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country   class  \
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K
#
#        Age Hours_per_Week
# 0    Adult      Full-Time
# 1    Adult      Part-Time
# 2    Adult      Full-Time
# 3  Elderly      Full-Time
# 4    Young      Full-Time

# %%
#Some columns like fnlwgt, education_num didn't give any perspective.
#Removed old age and hours_per_week columns
#Capital_Gain and Capital_Loss had many 0 values.
df = df.drop(['age','fnlwgt','education_num','hours_per_week','capital_loss', 'capital_gain'], axis = 1)
df.head()
# Out:
#            workclass   education       marital_status          occupation  \
# 0          State-gov   Bachelors        Never-married        Adm-clerical
# 1   Self-emp-not-inc   Bachelors   Married-civ-spouse     Exec-managerial
# 2            Private     HS-grad             Divorced   Handlers-cleaners
# 3            Private        11th   Married-civ-spouse   Handlers-cleaners
# 4            Private   Bachelors   Married-civ-spouse      Prof-specialty
#
#      relationship    race      sex  native_country   class      Age  \
# 0   Not-in-family   White     Male   United-States   <=50K    Adult
# 1         Husband   White     Male   United-States   <=50K    Adult
# 2   Not-in-family   White     Male   United-States   <=50K    Adult
# 3         Husband   Black     Male   United-States   <=50K  Elderly
# 4            Wife   Black   Female            Cuba   <=50K    Young
#
#   Hours_per_Week
# 0      Full-Time
# 1      Part-Time
# 2      Full-Time
# 3      Full-Time
# 4      Full-Time

# %%
#Removing space from the each item.
df = df.applymap(lambda space: space.strip() if type(space) is str else space)
#Here Preprocessing and Cleaning is completed

# %% [markdown]
# APRIORI ALGORITHM

# %%
#We will start the timer for Apriori Algorithm here
start_time = timeit.default_timer()
# Earlier we cleaned the dataframe. Now we will be using dataframe.values.tolist() to load the dataset.
def load_df():
    return df.values.tolist()
#First step is generating Candidate1.
def gen_cand1(itemset):
    CANDIDATE1 = []
    for i in itemset:
        for j in i:
            if not [j] in CANDIDATE1:
                CANDIDATE1.append([j])
    return list(map(frozenset, CANDIDATE1)) 
#Set in unhashable therefore we use frozenset which is nothing but immutable version of python set object.

itemset = load_df()
CANDIDATE1 = gen_cand1(itemset)

# %%
# Scanning Databse
def database_scan(Db, Ck, min_sup):
    sup_count = {}
    sup_data = {}
    r_list = []
    Db_length = len(Db)
    for t in Db:
        for i in Ck:
            if i.issubset(t):
                if not i in sup_count: sup_count[i]=1
                else: sup_count[i] += 1
    
    total_items = int(Db_length)
    for key in sup_count:
        support = sup_count[key]/total_items
        if support >= min_sup:
            r_list.insert(0,key)
        sup_data[key] = support
    return r_list, sup_data

#In this step we use our knowledge of support count. 
#If support of an item is greater than min_support, we insert that item and store it.

# Generating Apriori
def generate_apriori(L_k, k): 
    Ck = []
    for l in range(len(L_k)):
        for i in range(l+1, len(L_k)): 
            l1 = list(L_k[l])[:k-2]
            l2 = list(L_k[i])[:k-2]
            l1.sort()
            l2.sort()
            if l1==l2: 
                Ck.append(L_k[l] | L_k[i]) 
    return Ck

# %%
# Apriori function in which we specify min_sup and obtain frequent itemsets corresponding to it.
def apriori(itemset, min_sup = 0.12):
    CANDIDATE1 = gen_cand1(itemset)
    D = list(map(set, itemset))
    L1, sup_data = database_scan(D, CANDIDATE1, min_sup)
    L = [L1]
    k = 2
    while (len(L[k-2]) > 0):
        Ck = generate_apriori(L[k-2], k)
        L_k, sup = database_scan(D, Ck, min_sup)
        sup_data.update(sup)
        L.append(L_k)
        k += 1
    return L, sup_data
L,sdata = apriori(itemset)
new_list = []
for index in range(len(L)):
    print("\nL{} ".format(index))
    print("Number of patterns={} \n".format(len(L[index])))
    apriori_freq_pattern = [list(i) for i in L[index]]
    print(apriori_freq_pattern)
# Out:
# L0
# Number of patterns=24
#
# [['Craft-repair'], ['Own-child'], ['Some-college'], ['Overtime'], ['>50K'], ['Young'], ['Female'], ['Prof-specialty'], ['Elderly'], ['Divorced'], ['HS-grad'], ['Private'], ['Husband'], ['Exec-managerial'], ['Married-civ-spouse'], ['Full-Time'], ['Adult'], ['<=50K'], ['United-States'], ['Male'], ['White'], ['Not-in-family'], ['Never-married'], ['Bachelors']]
#
# L1
# Number of patterns=106
#
# [['White', 'Some-college'], ['Some-college', 'Full-Time'], ['<=50K', 'Some-college'], ['Overtime', '<=50K'], ['Never-married', 'Young'], ['White', 'Young'], ['Young', 'United-States'], ['Never-married', 'Own-child'], ['White', 'Own-child'], ['Own-child', 'United-States'], ['<=50K', 'Own-child'], ['Male', 'Young'], ['Male', 'Some-college'], ['Some-college', 'United-States'], ['Private', 'Some-college'], ['Private', 'Never-married'], ['Female', 'Never-married'], ['>50K', 'Adult'], ['>50K', 'Private'], ['Overtime', 'Adult'], ['Overtime', 'Private'], ['HS-grad', 'Married-civ-spouse'], ['HS-grad', 'Husband'], ['Elderly', 'White'], ['>50K', 'White'], ['Male', '>50K'], ['>50K', 'United-States'], ['>50K', 'Married-civ-spouse'], ['Husband', '>50K'], ['Overtime', 'White'], ['Male', 'Overtime'], ['Overtime', 'United-States'], ['Overtime', 'Married-civ-spouse'], ['Husband', 'Overtime'], ['White', 'Female'], ['Female', 'United-States'], ['Female', 'Adult'], ['<=50K', 'Female'], ['Female', 'Full-Time'], ['Private', 'Female'], ['<=50K', 'Young'], ['Young', 'Full-Time'], ['Private', 'Young'], ['Full-Time', 'Married-civ-spouse'], ['Husband', 'Full-Time'], ['Private', 'Married-civ-spouse'], ['Husband', 'Private'], ['Elderly', 'Male'], ['Elderly', 'United-States'], ['Elderly', '<=50K'], ['Elderly', 'Married-civ-spouse'], ['Not-in-family', 'Private'], ['White', 'Private'], ['Male', 'Private'], ['Private', 'United-States'], ['<=50K', 'Private'], ['Private', 'Adult'], ['Private', 'Full-Time'], ['HS-grad', 'White'], ['HS-grad', 'Male'], ['HS-grad', 'United-States'], ['HS-grad', '<=50K'], ['HS-grad', 'Adult'], ['HS-grad', 'Full-Time'], ['HS-grad', 'Private'], ['Divorced', 'United-States'], ['<=50K', 'Divorced'], ['White', 'Married-civ-spouse'], ['Male', 'Married-civ-spouse'], ['United-States', 'Married-civ-spouse'], ['<=50K', 'Married-civ-spouse'], ['Adult', 'Married-civ-spouse'], ['Husband', 'White'], ['Husband', 'Male'], ['Husband', 'United-States'], ['Husband', '<=50K'], ['Husband', 'Adult'], ['Husband', 'Married-civ-spouse'], ['Not-in-family', 'Never-married'], ['White', 'Bachelors'], ['White', 'Never-married'], ['White', 'Not-in-family'], ['Male', 'Never-married'], ['Male', 'Not-in-family'], ['Male', 'White'], ['Bachelors', 'United-States'], ['Never-married', 'United-States'], ['Not-in-family', 'United-States'], ['White', 'United-States'], ['Male', 'United-States'], ['<=50K', 'Never-married'], ['<=50K', 'Not-in-family'], ['<=50K', 'White'], ['Male', '<=50K'], ['<=50K', 'United-States'], ['White', 'Adult'], ['Male', 'Adult'], ['United-States', 'Adult'], ['<=50K', 'Adult'], ['Never-married', 'Full-Time'], ['Not-in-family', 'Full-Time'], ['White', 'Full-Time'], ['Male', 'Full-Time'], ['Full-Time', 'United-States'], ['<=50K', 'Full-Time'], ['Full-Time', 'Adult']]
#
# L2
# Number of patterns=223
#
# [['White', 'Private', 'Some-college'], ['Male', 'White', 'Some-college'], ['<=50K', 'White', 'Some-college'], ['Some-college', 'Full-Time', 'United-States'], ['White', 'Some-college', 'United-States'], ['<=50K', 'Some-college', 'United-States'], ['<=50K', 'Private', 'Some-college'], ['Male', 'Private', 'Young'], ['Overtime', 'White', '<=50K'], ['Male', '<=50K', 'Young'], ['Male', 'Young', 'United-States'], ['Male', 'White', 'Young'], ['Male', 'Private', 'Never-married'], ['Male', 'Overtime', '<=50K'], ['Overtime', '<=50K', 'United-States'], ['Overtime', 'Private', '<=50K'], ['<=50K', 'Private', 'Never-married'], ['Private', 'Young', 'United-States'], ['<=50K', 'Young', 'United-States'], ['<=50K', 'White', 'Young'], ['<=50K', 'Never-married', 'Young'], ['<=50K', 'Female', 'Never-married'], ['Private', 'Never-married', 'Full-Time'], ['Private', 'Never-married', 'Young'], ['<=50K', 'Own-child', 'United-States'], ['<=50K', 'White', 'Own-child'], ['<=50K', 'Never-married', 'Own-child'], ['White', 'Own-child', 'United-States'], ['Never-married', 'Own-child', 'United-States'], ['Full-Time', 'Young', 'United-States'], ['White', 'Young', 'Full-Time'], ['White', 'Young', 'United-States'], ['White', 'Never-married', 'Young'], ['White', 'Private', 'Young'], ['Never-married', 'Young', 'Full-Time'], ['Never-married', 'Young', 'United-States'], ['Male', 'Overtime', 'Adult'], ['Male', 'Overtime', 'Private'], ['Private', 'Some-college', 'United-States'], ['Male', 'Some-college', 'United-States'], ['Husband', 'Private', 'Adult'], ['Husband', 'White', 'Private'], ['Husband', 'Full-Time', 'Adult'], ['Husband', 'White', 'Full-Time'], ['Male', '>50K', 'Adult'], ['Male', '>50K', 'Private'], ['>50K', 'Private', 'Married-civ-spouse'], ['Married-civ-spouse', '>50K', 'Adult'], ['White', 'Private', 'Never-married'], ['Overtime', 'Private', 'United-States'], ['Overtime', 'White', 'Private'], ['Overtime', 'United-States', 'Adult'], ['Overtime', 'White', 'Adult'], ['>50K', 'Private', 'United-States'], ['>50K', 'White', 'Private'], ['>50K', 'United-States', 'Adult'], ['>50K', 'White', 'Adult'], ['Female', 'United-States', 'Never-married'], ['Private', 'Never-married', 'United-States'], ['Husband', 'Overtime', 'Married-civ-spouse'], ['Husband', 'Overtime', 'United-States'], ['Husband', 'Overtime', 'Male'], ['Husband', 'Overtime', 'White'], ['Married-civ-spouse', 'Overtime', 'United-States'], ['Male', 'Overtime', 'United-States'], ['Male', 'Overtime', 'White'], ['Male', 'Overtime', 'Married-civ-spouse'], ['Overtime', 'White', 'Married-civ-spouse'], ['Overtime', 'White', 'United-States'], ['Husband', '>50K', 'Married-civ-spouse'], ['Husband', '>50K', 'United-States'], ['Husband', '>50K', 'Male'], ['Husband', '>50K', 'White'], ['Married-civ-spouse', '>50K', 'United-States'], ['Male', '>50K', 'United-States'], ['Male', '>50K', 'White'], ['Male', '>50K', 'Married-civ-spouse'], ['>50K', 'White', 'Married-civ-spouse'], ['>50K', 'White', 'United-States'], ['Elderly', 'White', 'United-States'], ['Elderly', 'Male', 'White'], ['HS-grad', 'Husband', 'United-States'], ['HS-grad', 'Husband', 'Male'], ['HS-grad', 'United-States', 'Married-civ-spouse'], ['HS-grad', 'Male', 'Married-civ-spouse'], ['HS-grad', 'White', 'Married-civ-spouse'], ['HS-grad', 'Husband', 'Married-civ-spouse'], ['White', 'Full-Time', 'Married-civ-spouse'], ['White', 'Private', 'Married-civ-spouse'], ['Private', 'Adult', 'Married-civ-spouse'], ['Adult', 'Full-Time', 'Married-civ-spouse'], ['Private', 'Female', 'United-States'], ['<=50K', 'Female', 'United-States'], ['<=50K', 'White', 'Female'], ['Female', 'Full-Time', 'United-States'], ['Female', 'Adult', 'United-States'], ['White', 'Female', 'Full-Time'], ['White', 'Female', 'United-States'], ['White', 'Private', 'Female'], ['Private', 'Young', 'Full-Time'], ['<=50K', 'Young', 'Full-Time'], ['<=50K', 'Private', 'Young'], ['Private', 'Female', 'Full-Time'], ['<=50K', 'Female', 'Full-Time'], ['<=50K', 'Private', 'Female'], ['<=50K', 'Full-Time', 'Married ...
#
# L3
# Number of patterns=226
#
# [['White', 'United-States', 'Private', 'Some-college'], ['<=50K', 'White', 'United-States', 'Some-college'], ['Male', 'White', 'Young', 'Private'], ['Male', 'Young', 'United-States', 'Private'], ['Male', '<=50K', 'Young', 'Private'], ['<=50K', 'White', 'Husband', 'Private'], ['Male', 'Overtime', 'White', 'Private'], ['Male', 'Overtime', 'White', 'Adult'], ['Male', 'Overtime', '<=50K', 'White'], ['Overtime', 'White', '<=50K', 'United-States'], ['Male', 'White', 'Young', 'United-States'], ['Male', 'White', '<=50K', 'Young'], ['Male', '<=50K', 'Young', 'United-States'], ['Male', 'Overtime', '<=50K', 'United-States'], ['Male', 'Never-married', 'United-States', 'Private'], ['Male', '<=50K', 'Never-married', 'Private'], ['<=50K', 'White', 'Never-married', 'Private'], ['<=50K', 'Young', 'United-States', 'Private'], ['White', 'Never-married', 'Private', 'Full-Time'], ['Never-married', 'Young', 'United-States', 'Full-Time'], ['White', 'Young', 'United-States', 'Private'], ['White', 'Young', 'Private', 'Full-Time'], ['White', 'Never-married', 'Young', 'Private'], ['White', 'Never-married', 'Young', 'United-States'], ['White', 'Young', 'United-States', 'Full-Time'], ['<=50K', 'Never-married', 'Own-child', 'United-States'], ['<=50K', 'White', 'Own-child', 'United-States'], ['Never-married', 'Young', 'United-States', 'Private'], ['Never-married', 'United-States', 'Private', 'Full-Time'], ['<=50K', 'Never-married', 'United-States', 'Female'], ['<=50K', 'Never-married', 'Young', 'United-States'], ['<=50K', 'Never-married', 'Young', 'Full-Time'], ['<=50K', 'White', 'Never-married', 'Young'], ['<=50K', 'White', 'Young', 'United-States'], ['<=50K', 'White', 'Young', 'Full-Time'], ['<=50K', 'White', 'Young', 'Private'], ['<=50K', 'Young', 'United-States', 'Full-Time'], ['Young', 'United-States', 'Private', 'Full-Time'], ['<=50K', 'Never-married', 'United-States', 'Private'], ['<=50K', 'Never-married', 'Private', 'Full-Time'], ['<=50K', 'Never-married', 'Young', 'Private'], ['Male', 'Overtime', 'United-States', 'Private'], ['Male', 'Overtime', 'United-States', 'Adult'], ['Male', 'White', 'Married-civ-spouse', 'Full-Time'], ['Male', 'White', 'Married-civ-spouse', 'Private'], ['Male', 'White', 'Husband', 'Full-Time'], ['Male', 'Adult', 'Husband', 'Full-Time'], ['Male', 'White', 'Husband', 'Private'], ['Male', 'Adult', 'Husband', 'Private'], ['Male', 'Married-civ-spouse', 'Private', 'Adult'], ['Male', 'Married-civ-spouse', 'Full-Time', 'Adult'], ['Married-civ-spouse', 'White', 'Adult', '>50K'], ['United-States', 'Married-civ-spouse', '>50K', 'Adult'], ['Male', 'United-States', 'Adult', '>50K'], ['White', 'United-States', 'Husband', 'Full-Time'], ['White', 'Married-civ-spouse', 'Husband', 'Full-Time'], ['Married-civ-spouse', 'Adult', 'Husband', 'Full-Time'], ['White', 'United-States', 'Husband', 'Private'], ['White', 'Adult', 'Husband', 'Private'], ['White', 'Married-civ-spouse', 'Husband', 'Private'], ['White', 'Husband', 'Private', 'Full-Time'], ['United-States', 'Adult', 'Husband', 'Private'], ['Married-civ-spouse', 'Adult', 'Husband', 'Private'], ['White', 'United-States', 'Adult', '>50K'], ['White', 'United-States', '>50K', 'Private'], ['Overtime', 'White', 'United-States', 'Adult'], ['Overtime', 'White', 'United-States', 'Private'], ['White', 'Never-married', 'United-States', 'Private'], ['HS-grad', 'White', 'United-States', 'Married-civ-spouse'], ['HS-grad', 'Male', 'United-States', 'Married-civ-spouse'], ['HS-grad', 'Male', 'Married-civ-spouse', 'Husband'], ['HS-grad', 'Married-civ-spouse', 'United-States', 'Husband'], ['HS-grad', 'Male', 'United-States', 'Husband'], ['White', 'United-States', 'Married-civ-spouse', '>50K'], ['Male', 'White', 'Married-civ-spouse', '>50K'], ['Married-civ-spouse', 'Male', 'United-States', '>50K'], ['Male', 'White', 'United-States', '>50K'], ['Male', 'White', 'Husband', '>50K'], ['White', 'United-States', 'Husband', '>50K'], ['Male', 'United-States', 'Husband', '>50K'], ['White', 'Married-civ-spouse', 'Husband',  ...
#
# L4
# Number of patterns=107
#
# [['White', 'Full-Time', 'Male', '<=50K', 'Married-civ-spouse'], ['White', 'Husband', 'Private', 'Male', '<=50K'], ['White', 'Private', 'Male', '<=50K', 'Married-civ-spouse'], ['White', 'Husband', 'Private', '<=50K', 'Married-civ-spouse'], ['White', 'United-States', 'Male', 'Overtime', 'Adult'], ['White', 'United-States', 'Private', 'Male', 'Overtime'], ['White', 'United-States', 'Male', '<=50K', 'Young'], ['White', 'Never-married', 'United-States', 'Private', 'Full-Time'], ['Never-married', 'United-States', 'Private', 'Full-Time', '<=50K'], ['White', 'Private', 'Full-Time', '<=50K', 'Young'], ['White', 'United-States', 'Private', '<=50K', 'Young'], ['White', 'United-States', 'Full-Time', '<=50K', 'Young'], ['White', 'Never-married', 'United-States', '<=50K', 'Young'], ['Never-married', 'United-States', 'Private', '<=50K', 'Young'], ['White', 'Never-married', 'United-States', 'Private', 'Young'], ['United-States', 'Private', 'Full-Time', '<=50K', 'Young'], ['White', 'Never-married', 'Private', 'Full-Time', '<=50K'], ['White', 'Never-married', 'United-States', 'Private', '<=50K'], ['White', 'Never-married', 'Private', '<=50K', 'Young'], ['White', 'United-States', 'Husband', 'Full-Time', 'Male'], ['White', 'United-States', 'Full-Time', 'Male', 'Married-civ-spouse'], ['United-States', 'Husband', 'Private', 'Male', 'Adult'], ['White', 'Husband', 'Private', 'Male', 'Adult'], ['White', 'United-States', 'Husband', 'Private', 'Male'], ['White', 'United-States', 'Private', 'Male', 'Married-civ-spouse'], ['White', 'United-States', 'Husband', 'Private', 'Adult'], ['United-States', 'Private', 'Adult', 'Male', 'Married-civ-spouse'], ['United-States', 'Husband', 'Private', 'Adult', 'Married-civ-spouse'], ['Husband', 'Private', 'Adult', 'Male', 'Married-civ-spouse'], ['Husband', 'Full-Time', 'Adult', 'Male', 'Married-civ-spouse'], ['White', 'United-States', 'Husband', 'Full-Time', 'Married-civ-spouse'], ['White', 'United-States', 'Husband', 'Private', 'Married-civ-spouse'], ['White', 'Husband', 'Private', 'Adult', 'Married-civ-spouse'], ['White', 'Husband', 'Private', 'Full-Time', 'Married-civ-spouse'], ['White', 'Husband', 'Private', 'Full-Time', 'Male'], ['White', 'Husband', 'Private', 'Male', 'Married-civ-spouse'], ['White', 'Private', 'Adult', 'Male', 'Married-civ-spouse'], ['White', 'Husband', 'Full-Time', 'Male', 'Married-civ-spouse'], ['White', 'Private', 'Full-Time', 'Male', 'Married-civ-spouse'], ['White', 'United-States', 'Husband', 'Male', 'Overtime'], ['United-States', 'Husband', 'Male', 'Overtime', 'Married-civ-spouse'], ['White', 'Husband', 'Male', 'Overtime', 'Married-civ-spouse'], ['White', 'United-States', 'Male', 'Overtime', 'Married-civ-spouse'], ['White', 'United-States', 'Husband', 'Overtime', 'Married-civ-spouse'], ['White', 'United-States', 'Husband', 'Male', '>50K'], ['White', 'United-States', 'Male', 'Married-civ-spouse', '>50K'], ['United-States', 'Husband', 'Male', 'Married-civ-spouse', '>50K'], ['White', 'Husband', 'Male', 'Married-civ-spouse', '>50K'], ['White', 'United-States', 'Husband', 'Married-civ-spouse', '>50K'], ['HS-grad', 'United-States', 'Husband', 'Male', 'Married-civ-spouse'], ['White', 'United-States', 'Full-Time', '<=50K', 'Married-civ-spouse'], ['White', 'United-States', 'Private', '<=50K', 'Married-civ-spouse'], ['White', 'United-States', 'Private', 'Adult', 'Married-civ-spouse'], ['White', 'United-States', 'Private', 'Full-Time', 'Married-civ-spouse'], ['White', 'Private', 'Female', 'Full-Time', '<=50K'], ['White', 'United-States', 'Female', 'Full-Time', '<=50K'], ['White', 'United-States', 'Private', 'Female', '<=50K'], ['White', 'United-States', 'Private', 'Female', 'Full-Time'], ['United-States', 'Private', 'Female', 'Full-Time', '<=50K'], ['United-States', 'Husband', 'Private', 'Male', '<=50K'], ['United-States', 'Private', 'Male', '<=50K', 'Married-civ-spouse'], ['United-States', 'Husband', 'Full-Time', 'Male', 'Married-civ-spouse'], ['United-States', 'Husband', 'Private', '<=50K', 'Married- ...
#
# L5
# Number of patterns=16
#
# [['White', 'Husband', 'Private', 'Male', '<=50K', 'Married-civ-spouse'], ['White', 'Husband', 'Private', 'Full-Time', 'Male', 'Married-civ-spouse'], ['White', 'United-States', 'Husband', 'Private', 'Married-civ-spouse', 'Adult'], ['White', 'United-States', 'Private', 'Adult', 'Male', 'Married-civ-spouse'], ['White', 'United-States', 'Husband', 'Private', 'Male', 'Married-civ-spouse'], ['White', 'United-States', 'Husband', 'Private', 'Male', 'Adult'], ['White', 'Husband', 'Private', 'Married-civ-spouse', 'Male', 'Adult'], ['United-States', 'Husband', 'Private', 'Married-civ-spouse', 'Male', 'Adult'], ['White', 'United-States', 'Husband', 'Full-Time', 'Male', 'Married-civ-spouse'], ['White', 'United-States', 'Husband', 'Male', 'Married-civ-spouse', '>50K'], ['White', 'United-States', 'Husband', 'Male', 'Overtime', 'Married-civ-spouse'], ['United-States', 'Husband', 'Private', 'Full-Time', 'Male', 'Married-civ-spouse'], ['United-States', 'Husband', 'Private', 'Male', '<=50K', 'Married-civ-spouse'], ['White', 'United-States', 'Private', 'Full-Time', '<=50K', 'Male'], ['White', 'United-States', 'Husband', 'Married-civ-spouse', 'Male', 'Adult'], ['White', 'United-States', 'Husband', 'Male', '<=50K', 'Married-civ-spouse']]
#
# L6
# Number of patterns=1
#
# [['White', 'United-States', 'Husband', 'Private', 'Adult', 'Male', 'Married-civ-spouse']]
#
# L7
# Number of patterns=0
#
# []

# %%
end_time = timeit.default_timer() #ending timer
total_time = end_time - start_time
total_time
# Out:
# 6.483096700000004
