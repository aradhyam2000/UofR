# %%
#https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Coimbra
import warnings
warnings.filterwarnings('ignore')

#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import statistics
import scipy

# %%
df = pd.read_csv (r'dataR2.csv') #read data

# %%
df #show data
# Out:
#      Age        BMI  Glucose  Insulin      HOMA   Leptin  Adiponectin  \
# 0     48  23.500000       70    2.707  0.467409   8.8071     9.702400
# 1     83  20.690495       92    3.115  0.706897   8.8438     5.429285
# 2     82  23.124670       91    4.498  1.009651  17.9393    22.432040
# 3     68  21.367521       77    3.226  0.612725   9.8827     7.169560
# 4     86  21.111111       92    3.549  0.805386   6.6994     4.819240
# ..   ...        ...      ...      ...       ...      ...          ...
# 111   45  26.850000       92    3.330  0.755688  54.6800    12.100000
# 112   62  26.840000      100    4.530  1.117400  12.4500    21.420000
# 113   65  32.050000       97    5.730  1.370998  61.4800    22.540000
# 114   72  25.590000       82    2.820  0.570392  24.9600    33.750000
# 115   86  27.180000      138   19.910  6.777364  90.2800    14.110000
#
#      Resistin    MCP.1  Classification
# 0     7.99585  417.114               1
# 1     4.06405  468.786               1
# ...

# %%
df.head()
# Out:
#    Age        BMI  Glucose  Insulin      HOMA   Leptin  Adiponectin  Resistin  \
# 0   48  23.500000       70    2.707  0.467409   8.8071     9.702400   7.99585
# 1   83  20.690495       92    3.115  0.706897   8.8438     5.429285   4.06405
# 2   82  23.124670       91    4.498  1.009651  17.9393    22.432040   9.27715
# 3   68  21.367521       77    3.226  0.612725   9.8827     7.169560  12.76600
# 4   86  21.111111       92    3.549  0.805386   6.6994     4.819240  10.57635
#
#      MCP.1  Classification
# 0  417.114               1
# 1  468.786               1
# 2  554.697               1
# 3  928.220               1
# 4  773.920               1

# %%
df.describe() # Summarize data
# Out:
#               Age         BMI     Glucose     Insulin        HOMA      Leptin  \
# count  116.000000  116.000000  116.000000  116.000000  116.000000  116.000000
# mean    57.301724   27.582111   97.793103   10.012086    2.694988   26.615080
# std     16.112766    5.020136   22.525162   10.067768    3.642043   19.183294
# min     24.000000   18.370000   60.000000    2.432000    0.467409    4.311000
# 25%     45.000000   22.973205   85.750000    4.359250    0.917966   12.313675
# 50%     56.000000   27.662416   92.000000    5.924500    1.380939   20.271000
# 75%     71.000000   31.241442  102.000000   11.189250    2.857787   37.378300
# max     89.000000   38.578759  201.000000   58.460000   25.050342   90.280000
#
#        Adiponectin    Resistin        MCP.1  Classification
# count   116.000000  116.000000   116.000000      116.000000
# mean     10.180874   14.725966   534.647000        1.551724
# std       6.843341   12.390646   345.912663        0.499475
# ...

# %%
df_ = pd.DataFrame(df)

age = df_.iloc[:,[0]]
bmi = df_.iloc[:,[1]]
glucose = df_.iloc[:,[2]]
insulin = df_.iloc[:,[3]]
homa = df_.iloc[:,[4]]
leptin = df_.iloc[:,[5]]
adiponectin = df_.iloc[:,[6]]
resistin = df_.iloc[:,[7]]
mcp = df_.iloc[:,[8]]
classification = df_.iloc[:,[9]]

# %% [markdown]
#                                                 Statistics

# %%
df.skew(axis = 0, skipna = True) #Skewness
# Out:
# Age               0.017832
# BMI               0.170152
# Glucose           2.593305
# Insulin           2.577568
# HOMA              3.812087
# Leptin            1.309536
# Adiponectin       1.817765
# Resistin          2.577429
# MCP.1             1.424436
# Classification   -0.210748
# dtype: float64

# %%
age.describe() #Summarize
# Out:
#               Age
# count  116.000000
# mean    57.301724
# std     16.112766
# min     24.000000
# 25%     45.000000
# 50%     56.000000
# 75%     71.000000
# max     89.000000

# %%
age_mean = np.mean(age) #Mean
age_mean
# Out:
# Age    57.301724
# dtype: float64

# %%
age_median=np.median(age) #Median
age_median
# Out:
# 56.0

# %%
from scipy import stats #Mode
age_mode = stats.mode(age)

age_mode
# Out:
# ModeResult(mode=array([[45]], dtype=int64), count=array([[7]]))

# %%
age_sd = np.std(age) #Standard Deviation
age_sd
# Out:
# Age    16.043164
# dtype: float64

# %%
age_var = np.var(age) #Variance
age_var
# Out:
# Age    257.3831
# dtype: float64

# %%
age_75percentile = np.percentile(age, 75) #75th Percentile
age_75percentile
# Out:
# 71.0

# %%
age_25percentile = np.percentile(age, 25) #25th Percentile
age_25percentile
# Out:
# 45.0

# %%
IQR = age_75percentile - age_25percentile
IQR #Interquartile Range
# Out:
# 26.0

# %%
age_50percentile = np.percentile(age, 50) #50th Percentile (Median)
age_50percentile
# Out:
# 56.0

# %%
age_min = np.min(age) #Minimum
age_min
# Out:
# Age    24
# dtype: int64

# %%
age_max = np.max(age) #Maximum
age_max
# Out:
# Age    89
# dtype: int64

# %%
array_age = np.array(age) # Converting into array

# %%
geo_mean_age = statistics.geometric_mean(array_age) # Geometric Mean
geo_mean_age
# Out:
# 54.90472296718436

# %%
fmean_age = statistics.fmean(array_age) # Fmean
fmean_age
# Out:
# 57.30172413793103

# %%
medianlow_age = statistics.median_low(array_age) # Low Median
medianlow_age
# Out:
# array([55], dtype=int64)

# %%
medianhigh_age = statistics.median_high(array_age) # High Median
medianhigh_age
# Out:
# array([57], dtype=int64)

# %%
median_age = statistics.median_grouped(array_age, interval=2) # Median at interval=2 
median_age
# Out:
# array([56.])

# %%
quantile = statistics.quantiles(array_age, n=4, method='exclusive') #Quantile
quantile
# Out:
# [array([45.]), array([56.]), array([71.])]

# %%
# Reshaping into 1-D array
from collections import Counter
array_age = np.array(age)  
age_reshape = array_age.reshape((-1))
age_reshape
# Out:
# array([48, 83, 82, 68, 86, 49, 89, 76, 73, 75, 34, 29, 25, 24, 38, 44, 47,
#        61, 64, 32, 36, 34, 29, 35, 54, 45, 50, 66, 35, 36, 66, 53, 28, 43,
#        51, 67, 66, 69, 60, 77, 76, 76, 75, 69, 71, 66, 75, 78, 69, 85, 76,
#        77, 45, 45, 49, 34, 42, 68, 51, 62, 38, 69, 49, 51, 59, 45, 54, 64,
#        46, 44, 45, 44, 51, 72, 46, 43, 55, 43, 86, 41, 59, 81, 48, 71, 42,
#        65, 48, 85, 48, 58, 40, 82, 52, 49, 60, 49, 44, 40, 71, 69, 74, 66,
#        65, 72, 57, 73, 45, 46, 68, 75, 54, 45, 62, 65, 72, 86],
#       dtype=int64)

# %%
statistics.multimode(age_reshape) #Multimode
# Out:
# [45]

# %%
statistics.pstdev(age_reshape) #Population Standard Deviation
# Out:
# 16.0312195418814

# %%
statistics.pvariance(age_reshape) # Population Variance
# Out:
# 257

# %%
scipy.stats.rankdata(age_reshape) # Rank Data
# Out:
# array([ 40.5, 110. , 108.5,  80. , 114. ,  45. , 116. , 101.5,  93.5,
#         97.5,   8. ,   4.5,   2. ,   1. ,  14.5,  25.5,  38. ,  65. ,
#         68.5,   6. ,  12.5,   8. ,   4.5,  10.5,  56. ,  31. ,  48. ,
#         75. ,  10.5,  12.5,  75. ,  54. ,   3. ,  22. ,  50.5,  78. ,
#         75. ,  84. ,  63.5, 104.5, 101.5, 101.5,  97.5,  84. ,  88. ,
#         75. ,  97.5, 106. ,  84. , 111.5, 101.5, 104.5,  31. ,  31. ,
#         45. ,   8. ,  19.5,  80. ,  50.5,  66.5,  14.5,  84. ,  45. ,
#         50.5,  61.5,  31. ,  56. ,  68.5,  36. ,  25.5,  31. ,  25.5,
#         50.5,  91. ,  36. ,  22. ,  58. ,  22. , 114. ,  18. ,  61.5,
#        107. ,  40.5,  88. ,  19.5,  71. ,  40.5, 111.5,  40.5,  60. ,
#         16.5, 108.5,  53. ,  45. ,  63.5,  45. ,  25.5,  16.5,  88. ,
#         84. ,  95. ,  75. ,  71. ,  91. ,  59. ,  93.5,  31. ,  36. ,
#         80. ,  97.5,  56. ,  31. ,  66.5,  71. ,  91. , 114. ])

# %%
scipy.stats.zscore(age_reshape) # Z Score
# Out:
# array([-0.57979363,  1.60182096,  1.53948912,  0.66684328,  1.7888165 ,
#        -0.51746179,  1.97581204,  1.16549804,  0.97850251,  1.1031662 ,
#        -1.45243947, -1.7640987 , -2.01342608, -2.07575793, -1.20311209,
#        -0.82912101, -0.64212548,  0.23052036,  0.4175159 , -1.57710316,
#        -1.32777578, -1.45243947, -1.7640987 , -1.39010762, -0.20580256,
#        -0.76678917, -0.45512994,  0.54217959, -1.39010762, -1.32777578,
#         0.54217959, -0.2681344 , -1.82643054, -0.89145286, -0.3927981 ,
#         0.60451143,  0.54217959,  0.72917512,  0.16818851,  1.22782989,
#         1.16549804,  1.16549804,  1.1031662 ,  0.72917512,  0.85383882,
#         0.54217959,  1.1031662 ,  1.29016173,  0.72917512,  1.72648465,
#         1.16549804,  1.22782989, -0.76678917, -0.76678917, -0.51746179,
#        -1.45243947, -0.95378471,  0.66684328, -0.3927981 ,  0.29285221,
#        -1.20311209,  0.72917512, -0.51746179, -0.3927981 ,  0.10585667,
# ...

# %%
scipy.stats.ttest_1samp(age_reshape,0) #1-sample t-test
# Out:
# Ttest_1sampResult(statistic=38.30245364498922, pvalue=2.637950613425876e-67)

# %% [markdown]
# Using dataframe.describe(), we can get all the useful information like mean, median, quantiles, min and max. Apart from that functions can be directly applied using numpy library and statistics module to find the required values.

# %%
bmi.describe() # Summary of BMI Data
# Out:
#               BMI
# count  116.000000
# mean    27.582111
# std      5.020136
# min     18.370000
# 25%     22.973205
# 50%     27.662416
# 75%     31.241442
# max     38.578759

# %%
glucose.describe() # Summary of Glucose Data
# Out:
#           Glucose
# count  116.000000
# mean    97.793103
# std     22.525162
# min     60.000000
# 25%     85.750000
# 50%     92.000000
# 75%    102.000000
# max    201.000000

# %%
insulin.describe() # Summary of Insulin Data
# Out:
#           Insulin
# count  116.000000
# mean    10.012086
# std     10.067768
# min      2.432000
# 25%      4.359250
# 50%      5.924500
# 75%     11.189250
# max     58.460000

# %%
homa.describe() # Summary of HOMA Data
# Out:
#              HOMA
# count  116.000000
# mean     2.694988
# std      3.642043
# min      0.467409
# 25%      0.917966
# 50%      1.380939
# 75%      2.857787
# max     25.050342

# %%
leptin.describe() # Summary of Leptin Data
# Out:
#            Leptin
# count  116.000000
# mean    26.615080
# std     19.183294
# min      4.311000
# 25%     12.313675
# 50%     20.271000
# 75%     37.378300
# max     90.280000

# %%
adiponectin.describe() # Summary of Adiponectin Data
# Out:
#        Adiponectin
# count   116.000000
# mean     10.180874
# std       6.843341
# min       1.656020
# 25%       5.474283
# 50%       8.352692
# 75%      11.815970
# max      38.040000

# %%
resistin.describe() # Summary of Resistin Data
# Out:
#          Resistin
# count  116.000000
# mean    14.725966
# std     12.390646
# min      3.210000
# 25%      6.881763
# 50%     10.827740
# 75%     17.755207
# max     82.100000

# %%
mcp.describe() # Summary of MCP.1 Data
# Out:
#              MCP.1
# count   116.000000
# mean    534.647000
# std     345.912663
# min      45.843000
# 25%     269.978250
# 50%     471.322500
# 75%     700.085000
# max    1698.440000

# %%
classification.describe() # Summary of Classification Data
# Out:
#        Classification
# count      116.000000
# mean         1.551724
# std          0.499475
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max          2.000000

# %%
 #Frequency table
frq_table = pd.crosstab(index=df["Classification"], columns="People") 
frq_table
# Out:
# col_0           People
# Classification
# 1                   52
# 2                   64

# %%
df.groupby('Classification').mean() 
# Mean of Age, BMI, Glucose and other factors of 1. Healthy people 2. Patients
# Out:
#                       Age        BMI     Glucose    Insulin      HOMA  \
# Classification
# 1               58.076923  28.317336   88.230769   6.933769  1.552398
# 2               56.671875  26.984740  105.562500  12.513219  3.623342
#
#                    Leptin  Adiponectin   Resistin       MCP.1
# Classification
# 1               26.637933    10.328205  11.614813  499.730692
# 2               26.596512    10.061167  17.253777  563.016500

# %% [markdown]
# It can be observed that patients have significantly high glucose, insulin, HOMA, Resistin and MCP.1 levels compared to healthy people

# %%
spliting = df.groupby(df.Classification) #Spliting and grouping
healthy = spliting.get_group(1)
healthy
# Out:
#     Age        BMI  Glucose  Insulin      HOMA   Leptin  Adiponectin  \
# 0    48  23.500000       70    2.707  0.467409   8.8071     9.702400
# 1    83  20.690495       92    3.115  0.706897   8.8438     5.429285
# 2    82  23.124670       91    4.498  1.009651  17.9393    22.432040
# 3    68  21.367521       77    3.226  0.612725   9.8827     7.169560
# 4    86  21.111111       92    3.549  0.805386   6.6994     4.819240
# 5    49  22.854458       92    3.226  0.732087   6.8317    13.679750
# 6    89  22.700000       77    4.690  0.890787   6.9640     5.589865
# 7    76  23.800000      118    6.470  1.883201   4.3110    13.251320
# 8    73  22.000000       97    3.350  0.801543   4.4700    10.358725
# 9    75  23.000000       83    4.952  1.013839  17.1270    11.578990
# 10   34  21.470000       78    3.469  0.667436  14.5700    13.110000
# 11   29  23.010000       82    5.663  1.145436  35.5900    26.720000
# 12   25  22.860000       82    4.090  0.827271  20.4500    23.670000
# ...

# %%
patients = spliting.get_group(2)
patients
# Out:
#      Age        BMI  Glucose  Insulin      HOMA   Leptin  Adiponectin  \
# 52    45  21.303949      102   13.852  3.485163   7.6476    21.056625
# 53    45  20.829995       74    4.560  0.832352   7.7529     8.237405
# 54    49  20.956608       94   12.305  2.853119  11.2406     8.412175
# 55    34  24.242424       92   21.699  4.924226  16.7353    21.823745
# 56    42  21.359915       93    2.999  0.687971  19.0826     8.462915
# ..   ...        ...      ...      ...       ...      ...          ...
# 111   45  26.850000       92    3.330  0.755688  54.6800    12.100000
# 112   62  26.840000      100    4.530  1.117400  12.4500    21.420000
# 113   65  32.050000       97    5.730  1.370998  61.4800    22.540000
# 114   72  25.590000       82    2.820  0.570392  24.9600    33.750000
# 115   86  27.180000      138   19.910  6.777364  90.2800    14.110000
#
#      Resistin    MCP.1  Classification
# 52   23.03408  552.444               2
# 53   28.03230  382.955               2
# ...

# %%
#Reshaping Leptin into 1 D array
array_leptin = np.array(leptin)  
leptin_reshape = array_leptin.reshape((-1))
leptin_reshape
# Out:
# array([ 8.8071,  8.8438, 17.9393,  9.8827,  6.6994,  6.8317,  6.964 ,
#         4.311 ,  4.47  , 17.127 , 14.57  , 35.59  , 20.45  ,  8.88  ,
#        15.26  , 14.09  , 26.65  , 30.7729, 21.2117, 49.3727, 15.1248,
#        28.7502, 45.6196, 39.2134, 12.331 , 39.9802, 46.6401, 45.9624,
#        50.6094, 10.2809, 74.7069, 27.1841, 68.5102, 31.2128, 20.092 ,
#        21.9033, 16.2247, 83.4821, 24.2998, 21.7863, 28.562 , 35.891 ,
#        10.39  , 15.145 , 56.502 , 24.846 , 65.926 ,  6.633 , 45.272 ,
#         7.85  , 21.778 , 13.74  ,  7.6476,  7.7529, 11.2406, 16.7353,
#        19.0826,  9.6994, 11.0816,  9.8648,  8.438 , 32.58  ,  6.3339,
#         8.0163, 14.9037, 17.9973,  8.6874, 12.1905, 12.87  , 13.08  ,
#         7.65  , 18.16  ,  9.62  , 21.78  , 10.16  ,  9.8   , 37.2234,
#        25.7816, 47.647 , 44.7059, 17.022 , 38.8066, 46.076 , 19.0653,
#        12.2617, 26.5166, 15.5325, 70.8824, 18.1314, 22.8884, 31.0385,
# ...

# %%
# Normalizing Leptin Data
leptin_norm = (leptin_reshape - leptin_reshape.min())/ (leptin_reshape.max() - leptin_reshape.min())
leptin_norm
# Out:
# array([0.05229908, 0.05272598, 0.15852575, 0.06481057, 0.02778211,
#        0.02932103, 0.03085996, 0.        , 0.0018495 , 0.14907699,
#        0.11933371, 0.36384045, 0.18773046, 0.05314706, 0.12735986,
#        0.11375031, 0.25984948, 0.30780747, 0.19659063, 0.5241622 ,
#        0.1257872 , 0.28427922, 0.48050576, 0.40598821, 0.09328944,
#        0.4149077 , 0.49237632, 0.48449325, 0.53854762, 0.06944247,
#        0.81885214, 0.26606219, 0.74677151, 0.31292443, 0.18356617,
#        0.20463539, 0.13858135, 0.92092615, 0.23251172, 0.20327444,
#        0.28209006, 0.36734172, 0.07071154, 0.12602217, 0.60709093,
#        0.23886517, 0.71671184, 0.02700974, 0.47646245, 0.041166  ,
#        0.20317789, 0.10967907, 0.03881166, 0.04003652, 0.0806058 ,
#        0.1445207 , 0.17182473, 0.06267841, 0.0787563 , 0.06460236,
#        0.04800568, 0.32882783, 0.02353057, 0.04310042, 0.12321535,
#        0.15920041, 0.05090672, 0.09165513, 0.09955914, 0.10200188,
# ...

# %%
#Reshaping Homa into 1 D array
array_resistin = np.array(resistin)  
resistin_reshape = array_resistin.reshape((-1))
resistin_reshape
# Out:
# array([ 7.99585,  4.06405,  9.27715, 12.766  , 10.57635, 10.3176 ,
#        12.9361 ,  5.1042 ,  6.28445,  7.0913 ,  6.92   ,  4.58   ,
#         5.14   ,  6.85   ,  9.35   ,  7.64   ,  3.32   , 13.68392,
#         6.70188, 17.10223,  9.1539 ,  5.62592, 24.6033 , 16.43706,
#        10.19299,  8.70448, 11.78388, 23.3819 , 22.03703, 15.72187,
#        22.32024, 10.26309, 21.44366,  6.71026, 10.37518,  4.2075 ,
#         3.29175, 82.1    , 20.2535 , 17.2615 ,  8.04375,  8.4156 ,
#         7.5767 , 11.78796,  4.2989 ,  6.7052 ,  4.49685,  4.6638 ,
#         4.53   ,  9.6135 ,  8.49395, 11.774  , 23.03408, 28.0323 ,
#        23.1177 , 12.06534, 17.37615, 13.74244,  5.57055, 10.69548,
#        15.73606, 15.69876, 22.94254, 11.55492,  8.2049 ,  5.2633 ,
#        10.34455, 13.91245, 13.56   ,  4.62   ,  7.84   ,  5.31   ,
#         3.21   ,  4.82   ,  5.68   , 16.1    ,  7.16514, 38.6531 ,
#        24.3701 , 27.8325 , 31.6904 , 29.5583 , 10.15726, 42.7447 ,
# ...

# %%
np.cov(resistin_reshape, leptin_reshape) # Covariance
# Out:
# array([[153.52810031,  60.90501687],
#        [ 60.90501687, 367.99877146]])

# %%
np.corrcoef(resistin_reshape, leptin_reshape) # Correlation Coef
# Out:
# array([[1.        , 0.25623352],
#        [0.25623352, 1.        ]])

# %%
cc ,p = scipy.stats.pearsonr(resistin_reshape, leptin_reshape) # Pearson Correlation Coef
cc
# Out:
# 0.25623352151948275

# %%
p # P Value
# Out:
# 0.005497438746447219

# %%
scipy.stats.spearmanr(resistin_reshape, leptin_reshape)[0] # Spearman Correlation Coef
# Out:
# 0.13491715680621227

# %%
scipy.stats.kendalltau(resistin_reshape, leptin_reshape)[0] # Kendall Correlation Coef
# Out:
# 0.09535232383808095

# %%
scipy.stats.linregress(resistin_reshape, leptin_reshape) # Linear Regression
# Out:
# LinregressResult(slope=0.39670273223484603, intercept=20.773249280133964, rvalue=0.2562335215194826, pvalue=0.005497438746447281, stderr=0.14016200779780089, intercept_stderr=2.692638220623962)

# %%
stats.ttest_ind(resistin_reshape, leptin_reshape) # 2-Sample t-test
# Out:
# Ttest_indResult(statistic=-5.607123891175797, pvalue=5.871336900701827e-08)

# %% [markdown]
#      Applying Transformation

# %% [markdown]
# Log Transformation

# %%
from collections import Counter
array_homa = np.array(homa)  
homa_reshape = array_homa.reshape((-1))
homa_reshape
# Out:
# array([ 0.46740867,  0.70689733,  1.00965107,  0.61272493,  0.8053864 ,
#         0.73208693,  0.89078733,  1.88320133,  0.80154333,  1.01383947,
#         0.6674356 ,  1.14543613,  0.82727067,  1.33      ,  1.06967   ,
#         1.6       ,  0.59      ,  3.79014433,  1.03739367,  3.0099796 ,
#         0.92171933,  0.972138  ,  1.203832  ,  0.9067072 ,  1.229214  ,
#         1.38399733,  1.75261107,  2.05239   ,  1.513374  ,  1.30042667,
#         3.86978807,  2.53493167,  1.8404096 ,  5.09185613,  0.732193  ,
#         1.13392913,  0.84567693,  1.4066068 ,  1.30539453,  0.72755813,
#         1.1006464 ,  3.262364  ,  1.08963767,  1.245642  ,  2.098344  ,
#         1.341324  ,  1.8732508 ,  0.519184  ,  2.3498848 ,  1.0566016 ,
#         7.111918  ,  0.96027333,  3.4851632 ,  0.832352  ,  2.85311933,
#         4.9242264 ,  0.6879706 ,  1.55992   ,  1.0011016 ,  0.79018187,
#         1.23282767,  1.84629013,  0.507936  ,  0.69614267,  1.65877413,
# ...

# %%
from sklearn import preprocessing
a_homa = np.array(homa_reshape)
a_log = np.log([a_homa])
print(a_log)
# Out:
# [[-7.60551314e-01 -3.46869839e-01  9.60479294e-03 -4.89839166e-01
#   -2.16433117e-01 -3.11856011e-01 -1.15649564e-01  6.32973165e-01
#   -2.21216244e-01  1.37445761e-02 -4.04312373e-01  1.35785467e-01
#   -1.89623350e-01  2.85178942e-01  6.73501897e-02  4.70003629e-01
#   -5.27632742e-01  1.33240410e+00  3.67114782e-02  1.10193330e+00
#   -8.15145128e-02 -2.82575093e-02  1.85509802e-01 -9.79357035e-02
#    2.06374941e-01  3.24975930e-01  5.61106714e-01  7.19004968e-01
#    4.14341595e-01  2.62692416e-01  1.35319974e+00  9.30166681e-01
#    6.09988156e-01  1.62764243e+00 -3.11711139e-01  1.25688710e-01
#   -1.67617868e-01  3.41180279e-01  2.66505319e-01 -3.18061375e-01
#    9.58976436e-02  1.18245209e+00  8.58452254e-02  2.19651060e-01
#    7.41148462e-01  2.93657186e-01  6.27675317e-01 -6.55496931e-01
#    8.54366306e-01  5.50577200e-02  1.96177197e+00 -4.05373132e-02
#    1.24851487e+00 -1.83499851e-01  1.04841290e+00  1.59416719e+00
# ...

# %%
homalog = pd.DataFrame(a_log)
log_homa = homalog.T

# %%
plt.hist(log_homa, 8, color='bisque', alpha=1, rwidth=0.9, edgecolor="black", linewidth=1)
plt.title('Histogram after Log Transformation')
plt.xlabel('Log Homa')
plt.ylabel('Count')
plt.show()
#Histogram after Log Transformation

# %%
log_homa.skew(axis = 0, skipna = True) #Skewness
# Out:
# 0    0.913744
# dtype: float64

# %% [markdown]
# Reduced skewness of HOMA from 3.812 to 0.914 by applying log transformation.

# %% [markdown]
# SQRT Transformation

# %%
a_sqrt = np.sqrt([a_homa])
print(a_sqrt)
# Out:
# [[0.68367292 0.84077187 1.00481395 0.78276748 0.89743323 0.85562079
#   0.94381531 1.37229783 0.89528952 1.00689596 0.81696732 1.0702505
#   0.90954421 1.15325626 1.03424852 1.26491106 0.76811457 1.9468293
#   1.01852524 1.73492928 0.96006215 0.98597059 1.09719278 0.95221174
#   1.10869924 1.17643416 1.32386218 1.43261649 1.23019267 1.14036252
#   1.96717769 1.59214687 1.35661697 2.25651416 0.85568277 1.06486109
#   0.91960694 1.18600455 1.14253864 0.85297018 1.04911696 1.80620154
#   1.04385711 1.11608333 1.44856619 1.15815543 1.36866753 0.72054424
#   1.5329334  1.02791128 2.66681795 0.97993537 1.86685918 0.91233327
#   1.68911792 2.2190598  0.82943993 1.24896757 1.00055065 0.88892174
#   1.11032773 1.35878259 0.71269629 0.83435164 1.28793406 1.18432496
#   0.88952647 1.17383133 0.8616078  2.11382781 0.88354438 3.90964721
#   1.24970797 1.06994392 2.7993223  1.62160486 1.94294519 1.04861839
#   4.54210676 2.2960319  0.7781436  1.544351   2.64630372 1.69463624
# ...

# %%
homasqrt = pd.DataFrame(a_sqrt)
sqrt_homa = homasqrt.T

# %%
plt.hist(sqrt_homa, 8, color='bisque', alpha=1, rwidth=0.9, edgecolor="black", linewidth=1)
plt.title('Histogram after SQRT Transformation')
plt.xlabel('SQRT Homa')
plt.ylabel('Count')
plt.show()
#Histogram after SQRT Transformation

# %%
sqrt_homa.skew(axis = 0, skipna = True) # Skewness
# Out:
# 0    2.176163
# dtype: float64

# %% [markdown]
# Reduced skewness of HOMA from 3.812 to 2.176 by applying sqrt transformation.

# %% [markdown]
# CBRT Transformation

# %%
a_cbrt = np.cbrt([a_homa])
print(a_cbrt)
# Out:
# [[0.77606647 0.89081075 1.00320673 0.84935357 0.93039656 0.90126855
#   0.96218373 1.23490131 0.92891434 1.00459204 0.8739162  1.04630177
#   0.9387484  1.09972445 1.02270396 1.1696071  0.83872065 1.55914049
#   1.01231234 1.44384703 0.97319432 0.99062505 1.06378851 0.96788187
#   1.071213   1.11441022 1.20567017 1.27082758 1.14810627 1.09151227
#   1.56998581 1.36350087 1.22547606 1.72038392 0.90131208 1.04278627
#   0.94565958 1.12044593 1.09290043 0.89940625 1.03248228 1.48312403
#   1.02902842 1.07596402 1.28024247 1.10283676 1.23272246 0.8037243
#   1.32948117 1.01852202 1.92307216 0.98657845 1.51614605 0.9406665
#   1.41831701 1.70129387 0.88278842 1.15975817 1.00036707 0.92450448
#   1.07226169 1.22677989 0.79787771 0.88627007 1.18375661 1.11938785
#   0.92492372 1.11276588 0.90546795 1.64707385 0.9207723  2.481752
#   1.16021647 1.04610195 1.98625621 1.38026781 1.55706604 1.03215514
#   2.74265738 1.7404115  0.84600546 1.3360745  1.91319744 1.42140442
# ...

# %%
homacbrt = pd.DataFrame(a_cbrt)
cbrt_homa = homacbrt.T
plt.hist(cbrt_homa, 8, color='bisque', alpha=1, rwidth=0.9, edgecolor="black", linewidth=1)
plt.title('Histogram after CBRT Transformation')
plt.xlabel('CBRT Homa')
plt.ylabel('Count')
plt.show()
#Histogram after CBRT Transformation

# %%
cbrt_homa.skew(axis = 0, skipna = True)  # finding skewness
# Out:
# 0    1.699111
# dtype: float64

# %% [markdown]
# Reduced skewness of HOMA from 3.812 to 1.699 by applying cbrt transformation.

# %% [markdown]
# Comparing log, sqrt and cbrt transformation, we can infer that log transform works best followed by cbrt and sqrt respectively.

# %% [markdown]
#                                                   Plotting
# 1. Histograms

# %%
plt.hist(age,8, color='bisque', alpha=1, rwidth=0.9, edgecolor="black", linewidth=1)
plt.title('Age Histogram')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()
#Age Histogram

# %%
plt.hist(bmi, 8, color='bisque', alpha=1, rwidth=0.9, edgecolor="black", linewidth=1)
plt.title('BMI Histogram')
plt.xlabel('BMI')
plt.ylabel('Count')
plt.show()
#BMI Histogram

# %%
plt.hist(glucose, 8, color='bisque', alpha=1, rwidth=0.9, edgecolor="black", linewidth=1)
plt.title('Glucose Histogram')
plt.xlabel('Glucose')
plt.ylabel('Count')
plt.show()
#Glucose Histogram

# %%
plt.hist(insulin, 8, color='bisque', alpha=1, rwidth=0.9, edgecolor="black", linewidth=1)
plt.title('Insulin Histogram')
plt.xlabel('Insulin')
plt.ylabel('Count')
plt.show()
#Insulin Histogram

# %%
plt.hist(homa, 8, color='bisque', alpha=1, rwidth=0.9, edgecolor="black", linewidth=1)
plt.title('HOMA Histogram')
plt.xlabel('HOMA')
plt.ylabel('Count')
plt.show()
#HOMA Histogram

# %%
plt.hist(leptin, 8, color='bisque', alpha=1, rwidth=0.9, edgecolor="black", linewidth=1)
plt.title('Leptin Histogram')
plt.xlabel('Leptin')
plt.ylabel('Count')
plt.show()
#Leptin Histogram

# %%
#Normalized Leptin
plt.hist(leptin_norm, 8, color='bisque', alpha=1, rwidth=0.9, edgecolor="black", linewidth=1)
plt.title('Normalized Leptin Histogram')
plt.xlabel('Normalized Leptin')
plt.ylabel('Count')
plt.show()
#Normalized Leptin Histogram

# %%
plt.hist(adiponectin, 8, color='bisque', alpha=1, rwidth=0.9, edgecolor="black", linewidth=1)
plt.title(' Adiponectin Histogram')
plt.xlabel('Adiponectin')
plt.ylabel('Count')
plt.show()
#Adiponectin Histogram

# %%
plt.hist(resistin, 8, color='bisque', alpha=1, rwidth=0.9, edgecolor="black", linewidth=1)
plt.title('Resistin Histogram')
plt.xlabel('Resistin')
plt.ylabel('Count')
plt.show()
#Resistin Histogram

# %%
plt.hist(mcp, 8, color='bisque', alpha=1, rwidth=0.9, edgecolor="black", linewidth=1)
plt.title('MCP.1 Histogram')
plt.xlabel('MCP.1')
plt.ylabel('Count')
plt.show()
# MCP.1 Histogram

# %%
plt.hist(classification, 8, color='bisque', alpha=1, rwidth=1, edgecolor="black", linewidth=1)
plt.title(' Classification Histogram')
plt.xlabel('Classification')
plt.ylabel('Count')
plt.show()
# Classification Histogram

# %% [markdown]
# 2. Scatter Plots

# %%
a = plt.scatter(leptin, age )
b = plt.scatter(resistin, age )
c = plt.scatter(adiponectin, age)
plt.title(' Scatter Plot for Leptin,Resistin and Adiponectin wrt Age')
plt.xlabel('Leptin, Resistin and Adiponectin')
plt.ylabel('Age')
plt.legend((a, b, c),
           ('Leptin', 'Resistin', 'Adiponectin'),
           scatterpoints=1,
           ncol=1,
           fontsize=10)
plt.show()
#Scatter Plot for Leptin, Resistin, Adiponectin and Insulin wrt Age

# %%
a2 = plt.scatter(leptin, glucose )
b2 = plt.scatter(resistin, glucose )
c2 = plt.scatter(adiponectin, glucose)
plt.title('Scatter Plot for L, R and A wrt Glucose  ')
plt.xlabel('Leptin, Resistin and Adiponectin')
plt.ylabel('Glucose')
plt.legend((a2, b2, c2),
           ('Leptin', 'Resistin', 'Adiponectin'),
           scatterpoints=1,
           ncol=1,
           fontsize=10)
plt.show()
#Scatter Plot for Leptin, Resistin, Adiponectin wrt Glucose

# %%
a3 = plt.scatter(leptin,homa)
b3 = plt.scatter(resistin,homa)
c3 = plt.scatter(adiponectin,homa)
d3 = plt.scatter(insulin,homa)
plt.title('Scatter Plot for L, R, A and I wrt HOMA  ')
plt.xlabel('Leptin, Resistin, Adiponectin and Insulin')
plt.legend((a3, b3, c3, d3),
           ('Leptin', 'Resistin', 'Adiponectin','Insulin'),
           scatterpoints=1,
           ncol=1,
           fontsize=10)
plt.ylabel('HOMA')
plt.show()
#Scatter Plot for Leptin, Resistin, Adiponectin and Insulin wrt HOMA

# %%
plt.scatter(age, bmi)
plt.title('Scatter Plot for Age wrt BMI ')
plt.xlabel('Age')
plt.ylabel('BMI')
 # Scatter Plot for Age wrt BMI
# Out:
# Text(0, 0.5, 'BMI')

# %%
plt.scatter(resistin, classification)
plt.title('Scatter Plot for Resistin wrt Classification  ')
plt.xlabel('Resistin')
plt.ylabel('Classification')
# Scatter Plot for Resistin wrt Classification
# Out:
# Text(0, 0.5, 'Classification')

# %%
plt.scatter(glucose, classification)
plt.title('Scatter Plot for Glucose wrt Classification')
plt.xlabel('Glucose')
plt.ylabel('Classification')
# Scatter Plot for Glucose wrt Classification
# Out:
# Text(0, 0.5, 'Classification')

# %%
plt.scatter(homa, classification)
plt.title('Scatter Plot for HOMA wrt Classification ')
plt.ylabel('Classification')
plt.xlabel('HOMA')
# Scatter Plot for HOMA wrt Classification
# Out:
# Text(0.5, 0, 'HOMA')

# %%
a4= plt.scatter(glucose, classification)
b4= plt.scatter(resistin, classification)
c4= plt.scatter(age, classification)
d4= plt.scatter(bmi, classification)

plt.title('Scatter Plot for G, R, Age and BMI wrt Classification')
plt.xlabel('Leptin, Resistin, Adiponectin and Insulin')
plt.ylabel('Classification')
plt.legend((a4, b4, c4, d4),
           ('Glucose', 'Resistin', 'Age','BMI'),
           scatterpoints=1,
           ncol=1,
           fontsize=10)
plt.show()
# Scatter Plot for Glucose, Resistin, Age, BMI wrt Classification

# %% [markdown]
# 3. Scatter Matrix

# %%
import seaborn
seaborn.pairplot(df, vars=['Age','Glucose','Insulin','Leptin', 'Resistin', 'Adiponectin', 'HOMA','MCP.1','Classification']) # Scatter Matrix

# %% [markdown]
# 4. Heatmap

# %%
#Correlation Matrix
cor_matrix = df.corr()
round(cor_matrix,2)
sns.heatmap(cor_matrix)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 5. Bar Plot

# %%
x = np.array(leptin_reshape)
y = np.array(resistin_reshape)

plt.bar(x,y)
plt.title('Bar Plot for Leptin and Resistin')
plt.xlabel('Leptin')
plt.ylabel('Resistin')
plt.show()
#Bar Plot for Leptin and Resistin

# %%
y = np.array(age_reshape)
x = np.array(resistin_reshape)

plt.bar(x,y)
plt.title('Bar Plot for Age and Resistin')
plt.xlabel('Age')
plt.ylabel('Resistin')
plt.show()
#Bar Plot for Age and Resistin

# %%
x = np.array(leptin_reshape)
y = np.array(age_reshape)

plt.bar(x,y)
plt.title('Bar Plot for Leptin and Age')
plt.xlabel('Leptin')
plt.ylabel('Age')
plt.show()
#Bar Plot for Leptin and Age

# %%
x = np.array(homa_reshape)
y = np.array(age_reshape)

plt.bar(x,y)
plt.title('Bar Plot for HOMA and Age')
plt.xlabel('HOMA')
plt.ylabel('Age')
plt.show()
#Bar Plot for Homa and Age

# %% [markdown]
# 6. Box Plot

# %%
plt.boxplot(age_reshape)
plt.title('Box Plot for Age')
plt.ylabel('Age')
plt.show()
#Box Plot for Age

# %%
plt.boxplot(leptin_reshape)
plt.title('Box Plot for Leptin')
plt.ylabel('Leptin')
plt.show()
#Box Plot for Leptin

# %%
plt.boxplot(homa_reshape)
plt.title('Box Plot for HOMA')
plt.ylabel('HOMA')
plt.show()
#Box Plot for HOMA

# %% [markdown]
# Outliers

# %%
homa_25percentile = np.percentile(homa, 25) #25th Percentile of HOMA

# %%
homa_75percentile = np.percentile(homa, 75) #75th Percentile of HOMA

# %%
IQR_homa = homa_75percentile - homa_25percentile #IQR of HOMA

# %%
outliers = homa[((homa<(homa_25percentile-1.5*IQR_homa)) | (homa>(homa_75percentile+1.5*IQR_homa)))]
# Calculation Outliers

# %%
outliers.max() # Maximum Value
# Out:
# HOMA    25.050342
# dtype: float64

# %%
outliers.min() # Minimum Value
# Out:
# HOMA    5.96992
# dtype: float64

# %%
outliers.count() # No of Outliers
# Out:
# HOMA    12
# dtype: int64

# %% [markdown]
# 7. Lineplot

# %%
sns.lineplot( x = "BMI", y = "MCP.1",data = df) # Lineplot for BMI vs MCP.1
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='MCP.1'>

# %%
sns.lineplot( x = "HOMA", y = "Classification",data = df)  # Lineplot for HOMA vs Classification
# Out:
# <AxesSubplot:xlabel='HOMA', ylabel='Classification'>

# %%
sns.lineplot( x = "HOMA", y = "Insulin",data = df)  # Lineplot for HOMA vs Insulin
# Out:
# <AxesSubplot:xlabel='HOMA', ylabel='Insulin'>

# %% [markdown]
# 8. Normal Distribution Curve

# %%
age_mean
age_sd
age_data = np.linspace(age_mean - 3*age_sd, age_mean + 3*age_sd, 100)
plt.plot(age_data, stats.norm.pdf(age_data, age_mean, age_sd), color='yellow')
plt.show()
 # Normal Distribution Curve for Age

# %% [markdown]
# 9. QQ Plot

# %%
# QQ Plot for Normalized Leptin
import statsmodels.api as sm
import pylab as py
  

  
sm.qqplot(leptin_norm, line ='45')
py.show()

# %% [markdown]
# Right skewness is observed

# %% [markdown]
# 10. Density Plot

# %%
# Density plot for MCP.1

mcp.plot.density(color='blue')
plt.title('Density plot for MCP.1')
plt.show()

# %%
#Density Plot for Adiponectin
adiponectin.plot.density(color='blue')
plt.title('Density plot for Adiponectin')
plt.show()
