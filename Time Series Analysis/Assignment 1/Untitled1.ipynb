# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics
travel = pd.read_csv (r'BTS_Air_Rail_Vehicle_Miles.csv')

# %%
travel.Month = pd.to_datetime(read.Month,  format="%b-%y")

# %%
travel
# Out:
#          Month       Air       Rail  Vehicle
# 0   1990-01-01  35153577  454115779   163.28
# 1   1990-02-01  32965187  435086002   153.25
# 2   1990-03-01  39993913  568289732   178.42
# 3   1990-04-01  37981886  568101697   178.68
# 4   1990-05-01  38419672  539628385   188.88
# ..         ...       ...        ...      ...
# 167 2003-12-01  57795908  489403554   237.60
# 168 2004-01-01  53447972  410338691   217.30
# 169 2004-02-01  52608801  389778365   210.40
# 170 2004-03-01  63600019  453014590   247.50
# 171 2004-04-01  61887720  471116666   245.40
#
# [172 rows x 4 columns]

# %% [markdown]
# AIR

# %%
air = sns.lineplot(x = "Month", y = "Air" , data =travel )

plt.show()
# Out:
# C:\Users\aradh\AppData\Local\Temp/ipykernel_26984/312312814.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   air.set_xticklabels(air.get_xticklabels(), rotation=40, ha="right")

# %%
#Trend
air= travel[["Air"]] 
air.rolling(5).mean().plot(figsize=(12,5), linewidth=2, fontsize=14)
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %%
#Seasonality

air.diff().plot(figsize=(12,5), linewidth=2, fontsize=14)
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %%
amean = statistics.mean(travel.Air)
amean
# Out:
# 49257805.680232555

# %% [markdown]
# RAIL

# %%
sns.lineplot(x = "Month", y = "Rail" , data = travel)
plt.tight_layout()
plt.show()

# %%
#Trend
rail = travel[["Rail"]] 
rail.rolling(5).mean().plot(figsize=(12,5), linewidth=2, fontsize=14)
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %%
#Seasonality

rail.diff().plot(figsize=(12,5), linewidth=2, fontsize=14)
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %%
rmean = statistics.mean(travel.Rail)
rmean
# Out:
# 482755766.24418604

# %% [markdown]
# Vehicle

# %%
sns.lineplot(x = "Month", y = "Vehicle" , data = travel)
plt.tight_layout()
plt.show()

# %%
#Trend
vehicle = read[["Vehicle"]] 
vehicle.rolling(5).mean().plot(figsize=(12,5), linewidth=2, fontsize=14)
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %%
#Seasonality

vehicle.diff().plot(figsize=(12,5), linewidth=2, fontsize=14)
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %%
vmean = statistics.mean(travel.Vehicle)
vmean
# Out:
# 210.25058139534883

# %%
# SHAMPOO

# %%
shampoo = pd.read_csv (r'ShampooSales.csv')
shampoo
# Out:
#      Month  Shampoo Sales
# 0   Jan-95          266.0
# 1   Feb-95          145.9
# 2   Mar-95          183.1
# 3   Apr-95          119.3
# 4   May-95          180.3
# 5   Jun-95          168.5
# 6   Jul-95          231.8
# 7   Aug-95          224.5
# 8   Sep-95          192.8
# 9   Oct-95          122.9
# 10  Nov-95          336.5
# 11  Dec-95          185.9
# 12  Jan-96          194.3
# 13  Feb-96          149.5
# 14  Mar-96          210.1
# 15  Apr-96          273.3
# 16  May-96          191.4
# 17  Jun-96          287.0
# 18  Jul-96          226.0
# 19  Aug-96          303.6
# 20  Sep-96          289.9
# 21  Oct-96          421.6
# 22  Nov-96          264.5
# 23  Dec-96          342.3
# 24  Jan-97          339.7
# 25  Feb-97          440.4
# 26  Mar-97          315.9
# 27  Apr-97          439.3
# 28  May-97          401.3
# 29  Jun-97          437.4
# 30  Jul-97          575.5
# 31  Aug-97          407.6
# 32  Sep-97          682.0
# 33  Oct-97          475.3
# ...

# %%
shampoo.Month = pd.to_datetime(shampoo.Month,  format="%b-%y")
shampoo
# Out:
#         Month  Shampoo Sales
# 0  1995-01-01          266.0
# 1  1995-02-01          145.9
# 2  1995-03-01          183.1
# 3  1995-04-01          119.3
# 4  1995-05-01          180.3
# 5  1995-06-01          168.5
# 6  1995-07-01          231.8
# 7  1995-08-01          224.5
# 8  1995-09-01          192.8
# 9  1995-10-01          122.9
# 10 1995-11-01          336.5
# 11 1995-12-01          185.9
# 12 1996-01-01          194.3
# 13 1996-02-01          149.5
# 14 1996-03-01          210.1
# 15 1996-04-01          273.3
# 16 1996-05-01          191.4
# 17 1996-06-01          287.0
# 18 1996-07-01          226.0
# 19 1996-08-01          303.6
# 20 1996-09-01          289.9
# 21 1996-10-01          421.6
# 22 1996-11-01          264.5
# 23 1996-12-01          342.3
# 24 1997-01-01          339.7
# 25 1997-02-01          440.4
# 26 1997-03-01          315.9
# 27 1997-04-01          439.3
# 28 1997-05-01          401.3
# 29 1997-06-01          437.4
# 30 1997-07-01          575.5
# ...

# %%
sns.lineplot(x = "Month", y = "Shampoo Sales" , data =shampoo)

plt.tight_layout()
plt.show()
